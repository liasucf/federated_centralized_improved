# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('9953.csv', encoding='latin-1')
df1.set_index(pd.to_datetime(df1.Time), drop=True, append=False, inplace=True, verify_integrity=False)
df1 = df1.sort_index()

# %%
df1[1000:]
# Out:
#                                            Time  temperature   humidity  \
# Time
# 2020-06-09 23:01:01+00:00  2020-06-09T23:01:01Z    22.113333  61.768333
# 2020-06-09 23:31:01+00:00  2020-06-09T23:31:01Z    22.068333  62.070000
# 2020-06-10 00:01:01+00:00  2020-06-10T00:01:01Z    22.023333  62.248333
# 2020-06-10 00:31:01+00:00  2020-06-10T00:31:01Z    21.985000  62.355000
# 2020-06-10 01:01:01+00:00  2020-06-10T01:01:01Z    21.950000  62.383333
# ...                                         ...          ...        ...
# 2020-07-07 21:34:57+00:00  2020-07-07T21:34:57Z    27.655000  65.390000
# 2020-07-07 22:04:57+00:00  2020-07-07T22:04:57Z    27.636667  65.353333
# 2020-07-07 22:34:57+00:00  2020-07-07T22:34:57Z    27.613333  65.380000
# 2020-07-07 23:04:57+00:00  2020-07-07T23:04:57Z    27.598333  65.388333
# 2020-07-07 23:34:57+00:00  2020-07-07T23:34:57Z    27.583333  65.396667
#
#                                  tvoc          co2
# Time
# ...

# %%
df1.sort_values(ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-05904455adb6> in <module>
# ----> 1 df1.sort_values(ascending=True)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
df2 = df1.drop(columns = 'co2' )
df1.set_index(pd.to_datetime(df1.Time), drop=True).plot(subplots=True, figsize=(9,8))
plt.show()
