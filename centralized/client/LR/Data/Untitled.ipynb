# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import datetime

# %%
df1 = pd.read_csv('9953.csv', encoding='latin-1')
df1.set_index(pd.to_datetime(df1.Time), drop=True, append=False, inplace=True, verify_integrity=False)
df1 = df1.sort_index()

# %%
df1 = df1

# %%
df1 = df1.rename(columns={'tvoc': 'eTVOC', 'co2': 'CO2'})

# %%
df2 = df1.drop(columns = 'CO2' )
df1.plot(subplots=True, figsize=(9,8), xlim=(datetime.date(2020, 3, 15), datetime.date(2020, 7, 7)))

plt.show()
